# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthikeya546/SE1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
a = 10
b = 20

print("Sum =", a + b)
print("Product =", a * b)
# Out:
# Sum = 30
# Product = 200

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Sum =", a + b)
print("Difference =", a - b)
# Out:
# Enter first number: 5
# Enter second number: 4
# Sum = 9
# Difference = 1

# %%
with open("single_input.txt", "w") as file:
    file.write("25")

# %%
try:
    with open("single_input.txt", "r") as file:
        num = int(file.read())
    print("Number =", num)
    print("Square =", num * num)
except:
    print("Error reading file")
# Out:
# Number = 25
# Square = 625

# %%
with open("multiple_inputs.txt", "w") as file:
    file.write("10\n20\n30\n40")

# %%
try:
    with open("multiple_inputs.txt", "r") as file:
        numbers = file.readlines()

    numbers = [int(n.strip()) for n in numbers]

    print("Numbers:", numbers)
    print("Sum:", sum(numbers))
    print("Average:", sum(numbers)/len(numbers))
except:
    print("Error reading file")
# Out:
# Numbers: [10, 20, 30, 40]
# Sum: 100
# Average: 25.0

# %%
try:
    x = int(input("Enter a number: "))
    print(100 / x)
except ZeroDivisionError:
    print("Cannot divide by zero")
except ValueError:
    print("Invalid input")
# Out:
# Enter a number: 4
# 25.0

# %%
files = {
    "hardcoded.py": "a=10\nb=20\nprint(a+b)",
    "keyboard.py": "a=int(input())\nb=int(input())\nprint(a+b)",
    "single_file.py": "f=open('single_input.txt')\nprint(f.read())",
    "multiple_file.py": "f=open('multiple_inputs.txt')\nprint(f.readlines())"
}

for name, content in files.items():
    with open(name, "w") as f:
        f.write(content)

print("All versions saved")
# Out:
# All versions saved
